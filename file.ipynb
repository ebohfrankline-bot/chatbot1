# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
load_dotenv(override=True)  # Add override=True to be safe

openai_api_key = os.getenv('API_TOKEN')


if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:14]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-or-v1-1bd2b

# %%
import os
load_dotenv(override=True)  # Add override=True to be safe

openai_api_key = os.getenv('API_TOKEN')


if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:14]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-or-v1-1bd2b

# %%
from IPython.display import Markdown, display

response = openai_python_client.chat.completions.create(
    model="meta-llama/llama-3.2-3b-instruct",
    messages=[
        {"role": "user", "content": "what are the names of world leaders?"}
    ],
    stream=False
)

raw_response = response.choices[0].message.content

display(Markdown(raw_response))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from IPython.display import Markdown, display
# ----> 3 response = openai_python_client.chat.completions.create(
#       4     model="meta-llama/llama-3.2-3b-instruct",
#       5     messages=[
#       6         {"role": "user", "content": "what are the names of world leaders?"}
#       7     ],
#       8     stream=False
#       9 )
#      11 raw_response = response.choices[0].message.content
#      13 display(Markdown(raw_response))
#
# NameError: name 'openai_python_client' is not defined
